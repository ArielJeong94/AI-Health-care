# %% [markdown]
# <a href="https://colab.research.google.com/github/ArielJeong94/AI-Health-care/blob/main/1%E1%84%8B%E1%85%B5%E1%86%AF%E1%84%8E%E1%85%A1_%E1%84%87%E1%85%A7%E1%86%AB%E1%84%89%E1%85%AE%E1%84%8B%E1%85%AA_%E1%84%83%E1%85%A6%E1%84%8B%E1%85%B5%E1%84%90%E1%85%A5_%E1%84%90%E1%85%A1%E1%84%8B%E1%85%B5%E1%86%B8_%E1%84%89%E1%85%B5%E1%86%AF%E1%84%89%E1%85%B3%E1%86%B8%E1%84%80%E1%85%AA%E1%84%8C%E1%85%A6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 실습과제: 환자 기본정보 저장 및 계산하기
#
# 환자의 기본정보를 변수에 저장하고, 다양한 연산자를 활용하여 의료 정보를 계산하는 프로그램을 작성해보세요.
#
# ### 요구사항
#
# 1. **환자 기본정보 저장**
#    - 환자 이름: "박건강"
#    - 출생연도: 1990년
#    - 키: 170cm
#    - 몸무게: 65kg
#    - 성별: "남성"
#
# 2. **계산 작업**
#    - BMI 계산 (공식: 몸무게(kg) ÷ 키(m)²)
#    - 현재 나이 계산 (현재 연도: current_year)
#    - 성인 여부 판별 (18세 이상)
#
# 3. **출력 형식**
# ```
# === 환자 정보 ===
# 이름: 박건강 (남성, 35세)
# 키: 170cm, 몸무게: 65kg
# BMI: 22.5
# 출생연도: 1990년
# 성인 여부: True
# ```
#
# ### 힌트
# - BMI 계산 시 키를 cm에서 m로 변환해야 합니다
# - 현재 연도에서 출생연도를 빼면 나이가 나옵니다
# - 논리 연산자로 성인 여부를 확인하세요
# - f-string으로 깔끔하게 출력하세요

# %% [markdown]
# ## 💻 구현해보세요

# %%
# 현재 연도 자동 계산

from datetime import datetime

current_year = datetime.now().year

print(current_year)
# Out:
# 2025

# %%
# 여기에 코드를 작성하세요

# 1. 환자 기본정보 저장
patient_name = "박건강"
birth_year = 1990
height = 170
weight = 65
sex = "남성"

# 2. BMI 계산
height_m = height / 100
bmi = weight / (height_m ** 2)

# 3. 현재 나이 계산
from datetime import datetime

current_year = datetime.now().year

age = current_year - birth_year

# 4. 성인 여부 판별
is_adult = age >= 20

# 5. 결과 출력

print("=== 환자 정보 ===")
print(f"이름: {patient_name} ({sex}, {age}세)")
print(f"BMI: {bmi:.1f}")
print(f"출생연도: {birth_year}년")
print(f"성인 여부: {is_adult}")
# Out:
# === 환자 정보 ===
# 이름: 박건강 (남성, 35세)
# BMI: 22.5
# 출생연도: 1990년
# 성인 여부: True

# %%
# @title 정답

from datetime import datetime

# 1. 환자 기본정보 저장
patient_name = "박건강"      # 환자 이름
birth_year = 1990           # 출생연도
height_cm = 170             # 키 (cm)
weight = 65                 # 몸무게 (kg)
gender = "남성"             # 성별

# 2. BMI 계산
height_m = height_cm / 100              # 키를 미터로 변환
bmi = weight / (height_m ** 2)          # BMI 계산

# 3. 현재 나이 계산
current_year = datetime.now().year      # 현재 연도 자동 계산
age = current_year - birth_year         # 현재 나이 계산

# 4. 성인 여부 판별
is_adult = age >= 18                    # 성인 여부 (18세 이상)

# 5. 결과 출력
print("=== 환자 정보 ===")
print(f"이름: {patient_name} ({gender}, {age}세)")
print(f"키: {height_cm}cm, 몸무게: {weight}kg")
print(f"BMI: {bmi:.1f}")
print(f"출생연도: {birth_year}년")
print(f"성인 여부: {is_adult}")
# Out:
# === 환자 정보 ===
# 이름: 박건강 (남성, 35세)
# 키: 170cm, 몸무게: 65kg
# BMI: 22.5
# 출생연도: 1990년
# 성인 여부: True
